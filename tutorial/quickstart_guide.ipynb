# %% [markdown]
# Please see the various tutorials for more details. This is just a very brief quickstart guide.

# %% [markdown]
# Imports:

# %%
from SAM import SAM
from SAMGUI import SAMGUI #this is the interactive GUI
# %matplotlib inline

# %% [markdown]
# Initialize SAM

# %%
sam=SAM()

# %% [markdown]
# Load data from a file

# %%
sam.load_data('../example_data/schisto2.5_tpm.csv.gz')

# %% [markdown]
# Preprocess the data

# %%
sam.preprocess_data()

# %% [markdown]
# Run SAM

# %%
sam.run()
# Out:
# RUNNING SAM
# Iteration: 0, Convergence: 0.4490734323882737
# Iteration: 1, Convergence: 0.1264202533454181
# Iteration: 2, Convergence: 0.06942280436180137
# Iteration: 3, Convergence: 0.02088294675034242
# Iteration: 4, Convergence: 0.008136226911424176
# Computing the UMAP embedding...

# %% [markdown]
# Look at the 2D UMAP projection

# %%
sam.scatter()

# %% [markdown]
# Print top 20 ranked genes according to SAM weights

# %%
print(sam.adata.uns['ranked_genes'][:20])

# %% [markdown]
# Show the gene expression pattern of the top-ranked gene:

# %%
sam.show_gene_expression(sam.adata.uns['ranked_genes'][0]);

# %% [markdown]
# Launch the interactive GUI:

# %%
gui_obj = SAMGUI(sam)
gui_obj.SamPlot
